# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('orders.csv')

# %%
df.iloc[0:20]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df2 = pd.read_csv('order_products__train.csv')

# %%
df2.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df2.groupby('order_id').count().hist('product_id',bins=80)
plt.xlim(0,)
plt.title('Items per order')
plt.xlabel('# of items')
# Out:
# Text(0.5,0,'# of items')

# %%
df.groupby('user_id').count().hist('order_id',bins=50)
plt.xlim(0,)
plt.title('Orders per User')
plt.xlabel('# of Orders')
# Out:
# Text(0.5,0,'# of Orders')
